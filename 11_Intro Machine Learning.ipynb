# %% [markdown]
# # Machine Learning

# %% [markdown]
# ![image.png](attachment:5230f540-98a5-4fc8-9aec-b7f5c7a95aea.png)

# %% [markdown]
# # Regression Model

# %% [markdown]
# Model yang menghasilkan angka daripada kelas atau kategori

# %% [markdown]
# ![image.png](attachment:3b9cee4a-5e81-4a3c-9914-2b9e9cb6c4fc.png)

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:62b6698c-8225-4792-b04c-bb602f2191cd.png)

# %%
# provide data

x = np.array([5, 15, 25, 35, 45, 55])
y = np.array([5, 20, 14, 32, 22, 38])

print(x)
print(y)
# Out:
# [ 5 15 25 35 45 55]
# [ 5 20 14 32 22 38]

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels

# %% [markdown]
# ## Simple Linear Regression

# %%
print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [ 5 20 14 32 22 38]

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x,y)
r_sq
# Out:
# 0.715875613747954

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 5.633333333333333
# slope: [0.54]

# %%
new_model = LinearRegression().fit(x, y.reshape((-1, 1)))
print('intercept:', new_model.intercept_)
print('slope:', new_model.coef_)
# Out:
# intercept: [5.63333333]
# slope: [[0.54]]

# %%
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]

# %%
plt.scatter(x,y,alpha=0.5)
plt.plot(x,y_pred)

plt.title('Scatter Plot x and y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x
# Out:
# array([[ 5],
#        [15],
#        [25],
#        [35],
#        [45],
#        [55]])

# %%
x_new = np.arange(5,20,5).reshape([-1,1])
print(x_new)
# Out:
# [[ 5]
#  [10]
#  [15]]

# %%
y_new_pred = model.predict(x_new)
print(y_new_pred)
# Out:
# [ 8.33333333 11.03333333 13.73333333]

# %% [markdown]
# ## Multiple Linear Regression

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])
print(x, '\n', y)
# Out:
# [[ 0  1]
#  [ 5  1]
#  [15  2]
#  [25  5]
#  [35 11]
#  [45 15]
#  [55 34]
#  [60 35]]
#  [ 4  5 20 14 32 22 38 43]

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
r_sq_multi = model.score(x,y)
r_sq_multi
# Out:
# 0.8615939258756776

# %%
model.intercept_
# Out:
# 5.52257927519819

# %%
model.coef_
# Out:
# array([0.44706965, 0.25502548])

# %%
print('Formula Multiple LinReg adalah y = ', model.coef_[0], 'x1 +', model.coef_[1], 'x2 +', model.intercept_)
# Out:
# Formula Multiple LinReg adalah y =  0.44706964892412226 x1 + 0.2550254813137033 x2 + 5.52257927519819

# %%
y_pred_multi = model.predict(x)

# %%
y_pred_multi
# Out:
# array([ 5.77760476,  8.012953  , 12.73867497, 17.9744479 , 23.97529728,
#        29.4660957 , 38.78227633, 41.27265006])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse_multi = mean_squared_error(y, y_pred_multi)
mse_multi
# Out:
# 25.561871814835786

# %%
rmse = (mse_multi)**0.5
rmse
# Out:
# 5.055874980142981

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ![image.png](attachment:f7abf2b3-ea05-4ce8-b547-36de9877cc95.png)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([15, 11, 2, 8, 25, 32])

print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [15 11  2  8 25 32]

# %%
plt.scatter(x, y, alpha=0.5)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
y_pred = model.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
transformer = PolynomialFeatures(degree=2, include_bias=False)

# %%
transformer.fit(x)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
PolynomialFeatures(degree=2, include_bias=False, interaction_only=False, order='C')
# Out:
# PolynomialFeatures(include_bias=False)

# %%
x_ = transformer.transform(x)

# %%
x_ = PolynomialFeatures(degree=2, include_bias=False).fit_transform(x)

# %%
print(x_)
# Out:
# [[   5.   25.]
#  [  15.  225.]
#  [  25.  625.]
#  [  35. 1225.]
#  [  45. 2025.]
#  [  55. 3025.]]

# %%
model.score(x,y)
# Out:
# 0.4065969428801287

# %%
transformer = PolynomialFeatures(include_bias=False)

# %%
transformer.fit(x)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
x_poly = transformer.transform(x)
x_poly
# Out:
# array([[   5.,   25.],
#        [  15.,  225.],
#        [  25.,  625.],
#        [  35., 1225.],
#        [  45., 2025.],
#        [  55., 3025.]])

# %%
x_poly = transformer.fit_transform(x)
x_poly
# Out:
# array([[   5.,   25.],
#        [  15.,  225.],
#        [  25.,  625.],
#        [  35., 1225.],
#        [  45., 2025.],
#        [  55., 3025.]])

# %%
model_poly = LinearRegression()
model_poly.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
model_poly.score(x_poly,y)
# Out:
# 0.8908516262498563

# %%
model.score(x,y)
# Out:
# 0.4065969428801287

# %%
y_poly_pred = model_poly.predict(x_poly)

# %%
model = LinearRegression().fit(x, y)

# %%
plt.scatter(x,y,color='red',label='true y')
plt.plot(x,y_poly_pred,color='blue',label='predicted y')
plt.legend()
plt.show()

# %%
r_sq = model.score(x, y)
print('coeficient of determinan:', r_sq)
print('intercepy:' , model.intercept_)
print('coeficient:', model.coef_)
# Out:
# coeficient of determinan: 0.4065969428801287
# intercepy: 4.099999999999998
# coeficient: [0.38]

# %% [markdown]
# # Multiple Polynomial Regression

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])

# %%
x_poly = transformer.fit_transform(x)
model_poly = LinearRegression()
model = LinearRegression()
model_poly.fit(x_poly, y)
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print(model.score(x, y), model_poly.score(x_poly, y))
# Out:
# 0.8615939258756776 0.945370144912782

# %%
x_0 = [i[0] for i in x]

# %%
x_1 = [i[1] for i in x]

# %%
plt.scatter(x_0, y)

# %%
plt.scatter(x_1, y)

# %%
x_poly
# Out:
# array([[0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00],
#        [5.000e+00, 1.000e+00, 2.500e+01, 5.000e+00, 1.000e+00],
#        [1.500e+01, 2.000e+00, 2.250e+02, 3.000e+01, 4.000e+00],
#        [2.500e+01, 5.000e+00, 6.250e+02, 1.250e+02, 2.500e+01],
#        [3.500e+01, 1.100e+01, 1.225e+03, 3.850e+02, 1.210e+02],
#        [4.500e+01, 1.500e+01, 2.025e+03, 6.750e+02, 2.250e+02],
#        [5.500e+01, 3.400e+01, 3.025e+03, 1.870e+03, 1.156e+03],
#        [6.000e+01, 3.500e+01, 3.600e+03, 2.100e+03, 1.225e+03]])

# %%
y_pred = model.predict(x)
y_pred_poly = model_poly.predict(x_poly)
mse = mean_squared_error(y, y_pred)
mse_poly = mean_squared_error(y, y_pred_poly)
rmse = np.sqrt(mse)
rmse_poly = np.sqrt(mse_poly)
print(rmse, rmse_poly)
# Out:
# 5.055874980142981 3.176389674051434

# %% [markdown]
# # Advance Linear Regression with Statsmodels

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(x)

# %%
x
# Out:
# array([[ 1.,  0.,  1.],
#        [ 1.,  5.,  1.],
#        [ 1., 15.,  2.],
#        [ 1., 25.,  5.],
#        [ 1., 35., 11.],
#        [ 1., 45., 15.],
#        [ 1., 55., 34.],
#        [ 1., 60., 35.]])

# %%
model_stat = sm.OLS(y,x)

# %% [markdown]
# OLS = ordinary least square

# %%
result = model_stat.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     15.56
# Date:                Fri, 31 Mar 2023   Prob (F-statistic):            0.00713
# Time:                        20:14:57   Log-Likelihood:                -24.316
# No. Observations:                   8   AIC:                             54.63
# Df Residuals:                       5   BIC:                             54.87
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5226      4.431      1.246      0.268      -5.867      16.912
# ...

# %% [markdown]
# formula regresi : y = 5.5226 + 0.4471x1 + 0.2550x2

# %%
print('rsquared',result.rsquared)
# Out:
# rsquared 0.8615939258756776

# %%
result.params
# Out:
# array([5.52257928, 0.44706965, 0.25502548])

# %%
res_summary = result.summary()
res_summary
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     15.56
# Date:                Fri, 31 Mar 2023   Prob (F-statistic):            0.00713
# Time:                        20:15:11   Log-Likelihood:                -24.316
# No. Observations:                   8   AIC:                             54.63
# Df Residuals:                       5   BIC:                             54.87
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
res_summary = result.summary()
res_summary.tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
y_pred = result.predict(x)

# %%
mse = mean_squared_error(y, y_pred)
mse
# Out:
# 25.561871814835794

# %%
np.sqrt(mse)
# Out:
# 5.055874980142981

# %% [markdown]
# ## Implementing Linear Regression on Real Dataset

# %%
import statsmodels.api as sm
from sklearn import datasets

# %%
df = pd.read_csv('BostonHousing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x = df.drop('medv', axis=1)
y = df['medv']

# %%
x = x[['rm']]
model = sm.OLS(y,x)
results = model.fit()
predictions = results.predict(x)
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              4615.
# Date:                Fri, 31 Mar 2023   Prob (F-statistic):                   3.74e-256
# Time:                        20:15:47   Log-Likelihood:                         -1747.1
# No. Observations:                 506   AIC:                                      3496.
# Df Residuals:                     505   BIC:                                      3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x, y)
plt.plot(x, predictions)

# %% [markdown]
# ## Use SKLEARNS for Boston

# %%
X = df.drop('medv', axis=1)
y = df['medv']

# %%
linreg = LinearRegression()

# %%
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = linreg
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
linreg.score(X,y)
# Out:
# 0.7406426641094095

# %% [markdown]
# ## Contoh Kedua SKLearn

# %%
df = pd.read_csv('CarPrice_Assignment.csv',usecols=['horsepower','price'])
df
# Out:
#      horsepower    price
# 0           111  13495.0
# 1           111  16500.0
# 2           154  16500.0
# 3           102  13950.0
# 4           115  17450.0
# ..          ...      ...
# 200         114  16845.0
# 201         160  19045.0
# 202         134  21485.0
# 203         106  22470.0
# 204         114  22625.0
#
# [205 rows x 2 columns]

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['horsepower'].plot(kind='kde')

f.add_subplot(1,2,2)
df['horsepower'].plot(kind='box')

plt.show()

# %%
X = df['horsepower']
y = df['price']
plt.scatter(X,y)
plt.ylabel('price')
plt.xlabel('horsepower')
# Out:
# Text(0.5, 0, 'horsepower')

# %%
df.corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.808139
# price         0.808139  1.000000

# %%
X = X.to_frame()

# %% [markdown]
# # Data Splitting

# %% [markdown]
# ![image.png](attachment:cbc77075-b915-442d-b919-3845b825ac9d.png)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
linreg = LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linreg.score(X_train,y_train)
# Out:
# 0.6586012591316451

# %%
y_pred = linreg.predict(X_test)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred)

# %%
y_pred_train = linreg.predict(X_train)
y_pred_test = linreg.predict(X_test)

# %%
mse_train = mean_squared_error(y_train,y_pred_train)
mse_test = mean_squared_error(y_test,y_pred_test)
rmse_tr = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)
print('train mse:',mse_train)
print('test mse',mse_test)
print('train rmse',rmse_tr)
print('test rmse',rmse_test)
# Out:
# train mse: 21685232.735200476
# test mse 23510101.39456002
# train rmse 4656.740569883668
# test rmse 4848.721624774928
